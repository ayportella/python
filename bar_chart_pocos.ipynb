# %% [markdown]
# <a href="https://colab.research.google.com/github/ayportella/python/blob/main/bar_chart_pocos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploração de poços no Brasil ao longo dos anos** </br>
# Andressa Yumi Portella</br>
# Novembro de 2023

# %% [markdown]
# Esse é um projeto que une o uso da biblioteca bar chart race, ou um gráfico de corridas de barras animado, com dados públicos de poços perfurados nas bacias brasileiras desde o início da exploração brasileira. </br>
# Com essa visualização, é possível assimilar facilmente quais foram as bacias mais exploradas ao longo dos anos, que receberam maior atenção exploratória, e que se relacionam a maiores reservas de óleo e gás.

# %%
! pip install bar-chart-race
# Out:
# Collecting bar-chart-race
#   Downloading bar_chart_race-0.1.0-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from bar-chart-race) (1.5.3)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from bar-chart-race) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->bar-chart-race) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->bar-chart-race) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->bar-chart-race) (1.16.0)
# Installing collected packages: bar-chart-race
# Successfully installed bar-chart-race-0.1.0

# %% [markdown]
# Importanto bibliotecas e lendo o arquivo baixado no site da ANP:

# %%
import bar_chart_race as bcr

# %%
import pandas as pd

# %%
df_pocos = pd.read_excel('tabela-de-pocos.xlsx')

# %% [markdown]
# No arquivo original, foi adicionada uma coluna com o número de poços por linha, para que sejam contabilizados por ano e por bacia posteriormente. </br>
# Foram utilizados todos os poços, sem filtragem de classificação, mas isso poderia ter sido feito a depender da motivação do estudo.

# %%
df_pocos.head
# Out:
# <bound method NDFrame.head of                   POCO  NUMERO_POCOS      CADASTRO          OPERADOR  \
# 0         2-SGMB-33-BA             1  202450015700               NaN
# 1         2-SGMB-48-BA             1  202450018700               NaN
# 2        2-SFPM-153-BA             1  202400000100               NaN
# 3       2-SFPM-153A-BA             1  202400224700               NaN
# 4        2-SFPM-163-BA             1  202400224800               NaN
# ...                ...           ...           ...               ...
# 30561    8-SZ-441DP-SE             1   90120021254             Carmo
# 30562  6-BRSA-377D-RJS             1   74281021544         Petrobras
# 30563     7-ARG-601-RN             1   72100020930       3R Potiguar
# 30564    7-PIR-203D-AL             1    8115021241    Origem Alagoas
# 30565     9-FR-47D-RJS             1   74281025682  Petro Rio Jaguar
#
#        POCO_OPERADOR ESTADO      BACIA   BLOCO SIG_CAMPO              CAMPO  \
# 0      2SGMB0033  BA     BA     Camamu  Brasil       NaN                NaN
# 1      2SGMB0048  BA     BA     Camamu  Brasil       NaN                NaN
# 2      2SFPM0153  BA     BA  Recôncavo  Brasil       NaN                NaN
# 3      2SFPM0153R BA     BA  Recôncavo  Brasil       NaN                NaN
# 4      2SFPM0163  BA     BA  Recôncavo  Brasil       NaN                NaN
# ...              ...    ...        ...     ...       ...                ...
# 30561      8SZ441DSE     SE    Sergipe      SZ     SZ           SIRIRIZINHO
# 30562      6RO64DRJS     RJ     Campos      RO     RO              RONCADOR
# 30563      7ARG601RN     RN   Potiguar     ARG     ARG    ALTO DO RODRIGUES
# 30564     7PIR203DAL     AL    Alagoas     PIR     PIR                PILAR
# 30565     MDI1PN570U     RJ     Campos     NaN     FR                 FRADE
#
#        ... DADOS_DIRECIONAIS TESTE_A_CABO  TESTE_DE_FORMACAO CANHONEIO  \
# 0      ...               NaN          NaN                NaN       NaN
# 1      ...               NaN          NaN                NaN       NaN
# 2      ...               NaN          NaN                NaN       NaN
# 3      ...               NaN          NaN                NaN       NaN
# 4      ...               NaN          NaN                NaN       NaN
# ...    ...               ...          ...                ...       ...
# 30561  ...            Existe       Existe                NaN       NaN
# 30562  ...            Existe       Existe             Existe       NaN
# 30563  ...               NaN          NaN                NaN       NaN
# 30564  ...            Existe          NaN                NaN       NaN
# 30565  ...               NaN          NaN                NaN       NaN
#
#       TESTEMUNHO GEOQUIMICA                       SIG_SONDA  \
# 0            NaN        NaN                             NaN
# 1            NaN        NaN                             NaN
# 2            NaN        NaN                             NaN
# 3            NaN        NaN  SC-1
# 4            NaN        NaN                             NaN
# ...          ...        ...                             ...
# 30561        NaN        NaN                           SC-85
# 30562     Existe     Existe                           SS-49
# 30563        NaN        NaN                           SC-86
# 30564        NaN        NaN                           QG-02
# 30565        NaN        NaN                           SS-87
#
#                    NOM_SONDA ATINGIU_PRESAL     DHA_ATUALIZACAO
# 0                        NaN            NaN 2023-11-05 05:00:05
# 1                        NaN            NaN 2023-11-05 05:00:05
# 2                        NaN            NaN 2023-11-05 05:00:05
# 3                        NaN            NaN 2023-11-05 05:00:05
# 4                        NaN            NaN 2023-11-05 05:00:05
# ...                      ...            ...                 ...
# 30561  SONDA CONVENCIONAL 85            NaN 2023-11-05 05:00:05
# 30562              SEDCO 707              S 2023-11-05 05:00:05
# 30563  SONDA CONVENCIONAL 86            NaN 2023-11-05 05:00:05
# 30564      QUEIROZ GALVÃO 02            NaN 2023-11-05 05:00:05
# 30565         TRANSOCEAN 706              I 2023-11-05 05:00:05
#
# [30566 rows x 61 columns]>

# %% [markdown]
# Criando um dataframe com ocorrências de poços por bacia, agrupando-os por ano:

# %%
df_pocos_bcr = pd.DataFrame(df_pocos.groupby(['BACIA',df_pocos.CONCLUSAO.dt.year]).sum()['NUMERO_POCOS']).unstack().T.droplevel(level=0)
# Out:
# <ipython-input-56-653a4920b571>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pocos_bcr = pd.DataFrame(df_pocos.groupby(['BACIA',df_pocos.CONCLUSAO.dt.year]).sum()['NUMERO_POCOS']).unstack().T.droplevel(level=0)

# %%
df_pocos_bcr
# Out:
# BACIA      Acre  Alagoas  Almada  Amazonas  Araripe  Barreirinhas  \
# CONCLUSAO
# 1922.0      NaN      NaN     NaN       NaN      NaN           NaN
# 1925.0      NaN      NaN     NaN       NaN      NaN           NaN
# 1937.0      NaN      NaN     NaN       NaN      NaN           NaN
# 1938.0      NaN      NaN     NaN       NaN      NaN           NaN
# 1939.0      NaN      NaN     NaN       NaN      NaN           NaN
# ...         ...      ...     ...       ...      ...           ...
# 2019.0      NaN      1.0     NaN       3.0      NaN           NaN
# 2020.0      NaN      3.0     NaN       2.0      NaN           NaN
# 2021.0      NaN      NaN     NaN       2.0      NaN           NaN
# 2022.0      NaN      NaN     NaN       5.0      NaN           NaN
# 2023.0      NaN      NaN     NaN       7.0      NaN           NaN
#
# BACIA      Bragança - Vizeu  Camamu  Campos  Ceará  ...  Rio do Peixe  Santos  \
# CONCLUSAO                                           ...
# 1922.0                  NaN     1.0     NaN    NaN  ...           NaN     NaN
# 1925.0                  NaN     1.0     NaN    NaN  ...           NaN     NaN
# 1937.0                  NaN     NaN     NaN    NaN  ...           NaN     NaN
# 1938.0                  NaN     NaN     NaN    NaN  ...           NaN     NaN
# 1939.0                  NaN     NaN     NaN    NaN  ...           NaN     NaN
# ...                     ...     ...     ...    ...  ...           ...     ...
# 2019.0                  NaN     NaN    20.0    NaN  ...           NaN    26.0
# 2020.0                  NaN     NaN    18.0    NaN  ...           NaN    43.0
# 2021.0                  NaN     NaN    24.0    NaN  ...           NaN    29.0
# 2022.0                  NaN     NaN    36.0    NaN  ...           NaN    26.0
# 2023.0                  NaN     NaN    30.0    NaN  ...           NaN    33.0
#
# BACIA      Sergipe  Solimões  São Francisco  São Luís  Tacutu  Tucano Central  \
# CONCLUSAO
# 1922.0         NaN       NaN            NaN       NaN     NaN             NaN
# 1925.0         NaN       NaN            NaN       NaN     NaN             NaN
# 1937.0         NaN       NaN            NaN       NaN     NaN             NaN
# 1938.0         NaN       NaN            NaN       NaN     NaN             NaN
# 1939.0         NaN       NaN            NaN       NaN     NaN             NaN
# ...            ...       ...            ...       ...     ...             ...
# 2019.0        27.0       1.0            NaN       NaN     NaN             NaN
# 2020.0         1.0       NaN            NaN       NaN     NaN             NaN
# 2021.0         NaN       NaN            NaN       NaN     NaN             NaN
# 2022.0         1.0       NaN            NaN       NaN     NaN             NaN
# 2023.0         NaN       NaN            NaN       NaN     NaN             NaN
#
# BACIA      Tucano Norte  Tucano Sul
# CONCLUSAO
# 1922.0              NaN         NaN
# 1925.0              NaN         NaN
# 1937.0              NaN         NaN
# 1938.0              NaN         NaN
# 1939.0              NaN         NaN
# ...                 ...         ...
# 2019.0              NaN         NaN
# 2020.0              NaN         NaN
# 2021.0              NaN         NaN
# 2022.0              NaN         NaN
# 2023.0              NaN         NaN
#
# [89 rows x 37 columns]

# %% [markdown]
# Esses são os parâmetros escolhidos para a visualização, limitados pelas 10 maiores ocorrências por bacia por ano a fim de gerar uma melhor visualização:

# %%
bcr.bar_chart_race(df_pocos_bcr,
                   bar_label_size=7, tick_label_size=7,
                   fixed_max=True,figsize=(5,3), n_bars=10,
                   title='Poços Perfurados em cada Bacia por Ano')
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "
# <video width="860" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Salvando o arquivo no formato gif:

# %%
bcr.bar_chart_race(df_pocos_bcr,
                   filename='pocos.gif',
                   bar_label_size=7, tick_label_size=7,
                   fixed_max=True,figsize=(5,3), n_bars=10,
                   title='Poços Perfurados em cada Bacia por Ano')
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# Dentre os insights percebidos, temos:
#
# - O início da exploração se deu em terra, com as bacias de Recôncavo, Sergipe-Alagoas e Potiguar;
# - A exploração em mar começou a partir da década de 50, e o protagonismo da Bacia de Campos começa na década de 70;
# - As bacias de Recôncavo, Sergipe-Alagoas, Potiguar e Espírito Santo continuam com alta produção ao longo dos anos, o que configura um cenário muito positivo para movimentação de economias regionais em bacias maduras;
# - Há um destaque para a Bacia de Santos mais expressivo nos últimos anos por ser a maior bacia produtora atualmente.

# %% [markdown]
# Bibliografia
#
#
#
# *   https://www.dexplo.org/bar_chart_race/
# *   https://www.gov.br/anp/pt-br/assuntos/exploracao-e-producao-de-oleo-e-gas/dados-tecnicos/acervo-de-dados
